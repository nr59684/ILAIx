# %% [markdown]
# This script automates license label assignment by matching license IDs in a CSV file with preprocessed license text files. It leverages fuzzy matching to handle potential variations in license ID formats.
#
# Here's a breakdown of the steps:
#
# 1. **Load CSV Data:** The script reads a CSV file (assumed to be located at '../../data/raw/data2-0.csv') using pandas.
# 2. **Preprocessed License Directory:** It defines the directory containing preprocessed license text files (assumed to be '../../data/processed/preprocessed_licenses_txt').
# 3. **Iterate Through CSV Rows:** The script iterates through each row in the CSV data frame.
# 4. **Extract License ID and Family:** It extracts the license ID (assuming it's in a column named 'License ID') and license family from the current row.
# 5. **Clean License ID (Optional):** The code performs optional cleaning on the license ID, handling potential prefixes like "LicenseRef-scancode" or "LicenseRef-MB".
# 6. **Identify Label Columns:** It finds all columns containing the value 'x' (assuming these represent labels for the license).
# 7. **Fuzzy Matching for License Text:**
#    - The script iterates through filenames of preprocessed license text files.
#    - For each filename, it extracts the license name (without extension or specific patterns like "deprecated") and calculates a fuzzy matching score using `fuzz.ratio` from the `fuzzywuzzy` library. This score indicates the similarity between the license ID and the license name in the filename.
#    - It keeps track of the filename with the highest matching score.
# 8. **Match and Label Assignment:**
#    - If the best matching score is 100 (perfect match), the script opens the corresponding license text file and assigns the extracted text along with the license ID, family, and labels to a dictionary. This dictionary is then saved as a JSON file with the license ID as the filename in the '../../data/processed/preprocessed_licenses_json_2' directory.
#    - If no perfect match is found, the script creates a dictionary with the license ID, family, labels, and an empty text field. This dictionary is saved as a JSON file with the license ID as the filename in the '../../data/processed/preprocessed_licenses_unmatched' directory. Additionally, it keeps track of the unmatched license ID, best matching filename (if any), and the corresponding score for logging purposes.
# 9. **Print Unmatched Count:** After processing all CSV rows, the script prints the total number of unmatched licenses.
#
# **Notes:**
#
# - This code assumes specific column names and data formats in the CSV file. You might need to adjust it based on your actual data structure.
# - The script uses a simple fuzzy matching approach. Consider exploring more sophisticated techniques for license matching if needed.

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
import json

# Load the CSV file
df = pd.read_csv("../../data/raw/data2-0.csv")

# Directory containing preprocessed licenses
license_dir = "../../data/processed/preprocessed_licenses_txt"
count=0
unmatched_licenses = []

# Create a label dictionary
for index, row in df.iterrows():
    label_dict = {}
    license_id = row['License ID']  # Assuming a column named 'license_id'
    if "LicenseRef-scancode" in license_id:
        license_id = license_id[20:]
    elif "LicenseRef-MB" in license_id:
        license_id = license_id[14:]
    labels = [col for col in df.columns if row[col] == 'x']  # Get all columns with 'x'
    license_family = row['License Family']  # Get family

    best_match_score = 0
    best_match_filename = None

    for filename in os.listdir(license_dir):
        if filename.endswith(".txt"):
            filename_without_extension = os.path.splitext(filename)[0][:-13]
            if "deprecated" in filename_without_extension:
                filename_without_extension = filename_without_extension[11:]
            score = fuzz.ratio(license_id, filename_without_extension)
            if score > best_match_score:
                best_match_score = score
                best_match_filename = filename
        
    if best_match_score >= 100:
        with open(os.path.join(license_dir, best_match_filename), "r") as f:
            license_text = f.read()
            label_dict= {'name': license_id, 'family': license_family, 'labels': labels, 'text': license_text}
        with open(f"../../data/processed/preprocessed_licenses_json_2/{license_id}.json", "w") as f:
            json.dump(label_dict, f, indent=4)
    else:
        count+=1
        unmatched_licenses.append(license_id)
        print(f"No match found for: {license_id}, best match: {best_match_filename}, score: {best_match_score}")
        label_dict= {'name': license_id, 'family': license_family, 'labels': labels, 'text': ""}
        with open(f"../../data/processed/preprocessed_licenses_unmatched/{license_id}.json", "w") as f:
            json.dump(label_dict, f, indent=4)
        with open(f"../../data/processed/unmatchedText/{license_id}.txt", "w") as outfile:
            outfile.write("")
print(count)
# Out:
# No match found for: Adobe-Helvetica, best match: Adobe-Utopia_preprocessed.txt, score: 67
# No match found for: Adobe-utopia-license, best match: Adobe-Utopia_preprocessed.txt, score: 69
# No match found for: LicenseRef-Scancode-amd-historical, best match: Linux-man-pages-1-para_preprocessed.txt, score: 39
# No match found for: Aelfred2, best match: AdaCore-doc_preprocessed.txt, score: 42
# No match found for: AES256, best match: APSL-1.2_preprocessed.txt, score: 43
# No match found for: ams-fonts, best match: Lucida-Bitmap-Fonts_preprocessed.txt, score: 50
# No match found for: Apple-iOS-Sample-Code, best match: BSD-Source-Code_preprocessed.txt, score: 50
# No match found for: arc4-random-number-license, best match: Unlicense_preprocessed.txt, score: 46
# No match found for: Avisynth-C-Interface-Exception-GPL-2.0-or-later, best match: GCC-exception-2.0-note_preprocessed.txt, score: 55
# No match found for: Ayam, best match: Jam_preprocessed.txt, score: 57
# No match found for: BigInteger, best match: Intel_preprocessed.txt, score: 53
# No match found for: BrianGladman, best match: Brian-Gladman-2-Clause_preprocessed.txt, score: 71
# No match found for: BSD-3-Clause-with-Google-XGB-Patent-License, best match: BSD-3-Clause-No-Nuclear-License_preprocessed.txt, score: 68
# No match found for: BSD-2-Mike-Matsnev, best match: BSD-2-Clause-Patent_preprocessed.txt, score: 59
# No match found for: bsd-new-tcpdump, best match: xinetd_preprocessed.txt, score: 38
# No match found for: bsd-simplified-intel, best match: Lucida-Bitmap-Fonts_preprocessed.txt, score: 41
# No match found for: Bsdtar, best match: Barr_preprocessed.txt, score: 60
# No match found for: cmu-simple, best match: curl_preprocessed.txt, score: 43
# No match found for: cmu-mit, best match: deprecated_Nunit_preprocessed.txt, score: 50
# No match found for: Castor, best match: Kastrup_preprocessed.txt, score: 62
# No match found for: compuphase-exception-Apache-2.0, best match: eCos-exception-2.0_preprocessed.txt, score: 65
# No match found for: CC-BY-3.0-NZ, best match: CC-BY-3.0-NL_preprocessed.txt, score: 92
# No match found for: CrpytoSwift, best match: ClArtistic_preprocessed.txt, score: 48
# No match found for: Cup-Parser-Generator, best match: BSD-2-Clause-Patent_preprocessed.txt, score: 41
# No match found for: Cygnus, best match: gnuplot_preprocessed.txt, score: 46
# No match found for: LicenseRef-Scancode-dom4j, best match: Linux-syscall-note_preprocessed.txt, score: 42
# No match found for: EDL, best match: ADSL_preprocessed.txt, score: 57
# No match found for: Facebook-Patent-v2, best match: BSD-2-Clause-Patent_preprocessed.txt, score: 49
# No match found for: fatfs, best match: Afmparse_preprocessed.txt, score: 46
# No match found for: The-Festival-Speech-Synthesis-System, best match: MIT-Festival_preprocessed.txt, score: 42
# No match found for: FFTPACK, best match: FSFAP_preprocessed.txt, score: 50
# No match found for: Flavor-Artistic, best match: ClArtistic_preprocessed.txt, score: 72
# No match found for: LicenseRef-Scancode-flora-1.1, best match: Condor-1.1_preprocessed.txt, score: 41
# No match found for: FDLIBM, best match: FBM_preprocessed.txt, score: 67
# No match found for: FreeRTOS, best match: FreeBSD-DOC_preprocessed.txt, score: 53
# No match found for: Freescale-Semiconductor, best match: freertos-exception-2.0_preprocessed.txt, score: 40
# No match found for: frontier-1.0, best match: Interbase-1.0_preprocessed.txt, score: 64
# No match found for: gary-s-brown, best match: SSLeay-standalone_preprocessed.txt, score: 41
# No match found for: GPL-2.0-or-later-Autoconf-exception, best match: deprecated_GPL-2.0-with-autoconf-exception_preprocessed.txt, score: 82
# No match found for: GPL-2.0-or-later-with-GNAT-exception, best match: deprecated_GPL-2.0-with-GCC-exception_preprocessed.txt, score: 77
# No match found for: GPL-v2.0-with-Linux-Syscall-Note, best match: Linux-syscall-note_preprocessed.txt, score: 64
# No match found for: GPL-2.0-with-Universal-FOSS-exception-1.0, best match: Universal-FOSS-exception-1.0_preprocessed.txt, score: 81
# No match found for: GPL-3.0-or-later-Autoconf-exception, best match: deprecated_GPL-3.0-with-autoconf-exception_preprocessed.txt, score: 82
# No match found for: GPL-3.0-with-bison-exception-2.2, best match: deprecated_GPL-2.0-with-bison-exception_preprocessed.txt, score: 90
# No match found for: Go-BSD-3-Clause-with-Patent-License, best match: BSD-3-Clause-No-Military-License_preprocessed.txt, score: 72
# No match found for: google-patent-license-golang, best match: Unlicense_preprocessed.txt, score: 43
# No match found for: google-patent-license-webm, best match: Unlicense_preprocessed.txt, score: 46
# No match found for: google-patent-license-webrtc, best match: Unlicense_preprocessed.txt, score: 43
# No match found for: ibm-dhcp, best match: Libpng_preprocessed.txt, score: 43
# No match found for: ilmid, best match: Glide_preprocessed.txt, score: 60
# No match found for: LicenseRef-Scancode-indiana-extreme-1.2, best match: erlang-otp-linking-exception_preprocessed.txt, score: 39
# No match found for: indiana-extreme, best match: MIT-testregex_preprocessed.txt, score: 43
# No match found for: INEGI, best match: IJG_preprocessed.txt, score: 50
# No match found for: INPOLY, best match: NGPL_preprocessed.txt, score: 60
# No match found for: iNRIA-Proj, best match: CNRI-Python_preprocessed.txt, score: 57
# No match found for: itu-t-gpl, best match: Ubuntu-font-1.0_preprocessed.txt, score: 42
# No match found for: Jasper-Arev-Fonts, best match: JasPer-2.0_preprocessed.txt, score: 44
# No match found for: jdom, best match: dtoa_preprocessed.txt, score: 50
# No match found for: JTidy, best match: Glide_preprocessed.txt, score: 40
# No match found for: Jython-2.0, best match: Python-2.0_preprocessed.txt, score: 90
# No match found for: KAZ, best match: FDK-AAC_preprocessed.txt, score: 40
# No match found for: KSH, best match: SHL-0.5_preprocessed.txt, score: 40
# No match found for: BCL, best match: NCL_preprocessed.txt, score: 67
# No match found for: LGPL-3.0-with-libfreefare-exception, best match: GPL-3.0-interface-exception_preprocessed.txt, score: 77
# No match found for: Libtool-Exception-LGPL-2.1-or-later, best match: LGPL-2.1-or-later_preprocessed.txt, score: 65
# No match found for: libaes, best match: Zlib_preprocessed.txt, score: 60
# No match found for: Libmng, best match: Libpng_preprocessed.txt, score: 83
# No match found for: liboil, best match: libtiff_preprocessed.txt, score: 62
# No match found for: libwebsockets-exception, best match: Libtool-exception_preprocessed.txt, score: 65
# No match found for: LLVM-Release-License, best match: LLVM-exception_preprocessed.txt, score: 53
# No match found for: Martin-Bergmeier, best match: Martin-Birgmeier_preprocessed.txt, score: 94
# No match found for: MATPLOTLIB-1.3.0-or-later, best match: AGPL-1.0-or-later_preprocessed.txt, score: 76
# No match found for: mit-license-1998, best match: Unlicense_preprocessed.txt, score: 56
# No match found for: mit-old-style, best match: Abstyles_preprocessed.txt, score: 48
# No match found for: MIT-Old-Legal, best match: MIT-enna_preprocessed.txt, score: 57
# No match found for: MIT-OldStyle-NoAds, best match: MIT-testregex_preprocessed.txt, score: 45
# No match found for: MIT-v2-Ad, best match: MIT-0_preprocessed.txt, score: 57
# No match found for: Netcat, best match: Leptonica_preprocessed.txt, score: 53
# No match found for: NeuQuant, best match: deprecated_Nunit_preprocessed.txt, score: 62
# No match found for: Numerical-Toolkit-License, best match: BSD-3-Clause-No-Military-License_preprocessed.txt, score: 46
# No match found for: Object-Code-Exception-MIT, best match: eCos-exception-2.0_preprocessed.txt, score: 60
# No match found for: OpenSymphony-1.1, best match: OpenPBS-2.3_preprocessed.txt, score: 52
# No match found for: OpenScene-Graph-Public, best match: Graphics-Gems_preprocessed.txt, score: 40
# No match found for: openssl-exception-lgpl3.0plus, best match: eCos-exception-2.0_preprocessed.txt, score: 64
# No match found for: OpenTCP, best match: OpenSSL_preprocessed.txt, score: 57
# No match found for: Opus, best match: mplus_preprocessed.txt, score: 67
# No match found for: OZPLB-1.0, best match: OPL-1.0_preprocessed.txt, score: 88
# No match found for: PCCTS-PD-with-Fallback, best match: NIST-PD-fallback_preprocessed.txt, score: 63
# No match found for: PCRE, best match: SCEA_preprocessed.txt, score: 50
# No match found for: Port-Audio, best match: AdaCore-doc_preprocessed.txt, score: 48
# No match found for: ppp-further, best match: softSurfer_preprocessed.txt, score: 48
# No match found for: PPP-IPV6-Control-Protocol-License, best match: BSD-3-Clause-No-Military-License_preprocessed.txt, score: 43
# No match found for: Proxool, best match: Xerox_preprocessed.txt, score: 50
# No match found for: PSF-2.3, best match: PSF-2.0_preprocessed.txt, score: 86
# No match found for: Public-Domain, best match: libutil-David-Nugent_preprocessed.txt, score: 42
# No match found for: punycode, best match: Soundex_preprocessed.txt, score: 53
# No match found for: Python-2.1.1, best match: Python-2.0.1_preprocessed.txt, score: 92
# No match found for: Qt-Exception-1.1-LGPL-2.1-only, best match: LGPL-2.1-only_preprocessed.txt, score: 60
# No match found for: red-hat-attribution, best match: BSD-3-Clause-Attribution_preprocessed.txt, score: 56
# No match found for: RedHat, best match: Zed_preprocessed.txt, score: 44
# No match found for: RIPEMD-160-License, best match: Unlicense_preprocessed.txt, score: 44
# No match found for: rxtx-exception-lgpl-2.1, best match: Font-exception-2.0_preprocessed.txt, score: 68
# No match found for: secret-labs-2011, best match: etalab-2.0_preprocessed.txt, score: 62
# No match found for: smail-gpl, best match: mailprio_preprocessed.txt, score: 59
# No match found for: Spencer-97, best match: Spencer-94_preprocessed.txt, score: 90
# No match found for: SpreadsheetML, best match: DocBook-Stylesheet_preprocessed.txt, score: 45
# No match found for: SQLite-Wrapper, best match: TCP-wrappers_preprocessed.txt, score: 54
# No match found for: SQLite-License, best match: Unlicense_preprocessed.txt, score: 52
# No match found for: SyncML-Toolkit-License, best match: Unlicense_preprocessed.txt, score: 52
# No match found for: LicenseRef-Scancode-synopsys-attribution, best match: BSD-3-Clause-Attribution_preprocessed.txt, score: 41
# No match found for: Sysctl, best match: Sleepycat_preprocessed.txt, score: 53
# No match found for: Takuya-OOURA, best match: any-OSI_preprocessed.txt, score: 42
# No match found for: Kannel-Software-License-v1.0, best match: BSD-3-Clause-No-Military-License_preprocessed.txt, score: 47
# No match found for: ldap-sdk-free-use, best match: Brian-Gladman-2-Clause_preprocessed.txt, score: 41
# No match found for: Unicode-2004-License, best match: Unicode-3.0_preprocessed.txt, score: 58
# No match found for: Unique, best match: Unlicense_preprocessed.txt, score: 53
# No match found for: Notre-Dame, best match: Bitstream-Vera_preprocessed.txt, score: 50
# No match found for: free-fork, best match: diffmark_preprocessed.txt, score: 47
# No match found for: W3C-IPR-Software-Notice, best match: NIST-Software_preprocessed.txt, score: 56
# No match found for: xmlproc, best match: mailprio_preprocessed.txt, score: 67
# 120
